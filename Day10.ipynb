# %%
#Day 10: Monitoring Station

from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#------------------FUNCIONES--------------------------------------------
import math
def asteroides():
        a1 =str()
        with open('/content/drive/My Drive/Colab Notebooks/Input_day10.txt') as f:
            for y, line in enumerate(f.readlines()):
                for x, a in enumerate(line):
                    if a == '#':
                        yield (x, y)
        

def angle(start, end):
        result = math.atan2(end[0] - start[0], start[1] - end[1]) * 180 / math.pi
        if result < 0:
            return 360 + result
        return result



def Part1(coordinates):
  
  m1=0
  result = None
  
  for start in coordinates:
       
    cnt1 = len(set(angle(start,end) for end in coordinates if start != end))
    if cnt1 > m1:
            m1 = cnt1
            result = start

  print('El resultado es {}'.format(m1))
  print('En la poscicion (x,y)=({},{})'.format(*result) )

# %%
asteroides = list(asteroides())
Part1(asteroides)
# Out:
# El resultado es 284
# En la poscicion (x,y)=(20,19)
